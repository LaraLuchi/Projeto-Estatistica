# %% [markdown]
# <a href="https://colab.research.google.com/github/LaraLuchi/Projeto-Estatistica/blob/main/Projeto_Estatistica.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Imports

# %% [markdown]
# ---
#
#
#
# Import numpy, matplot and pandas
#
#
#
# ---

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from google.colab import drive
# %matplotlib inline

# %% [markdown]
# ---
#
#
# Para iniciar, importar o banco de dados do .zip
# https://drive.google.com/file/d/1CcyhsgC5ZtG-CBFsy5giBqjNmBEpu4ej/view?usp=sharing
# (deixar no diretório inicial do drive)
#
#
# ---

# %%
drive.mount('/dados_cancer_mama') #access location for Google Drive!

# %cd /dados_cancer_mama


import zipfile

def unzip(path, destiny):
  with zipfile.ZipFile(path, 'r') as zip_ref:
      zip_ref.extractall(destiny)


unzip("/dados_cancer_mama/MyDrive/archive.zip", "/dados_cancer_mama/MyDrive/Projeto Estatistica/")
#access to information
# Out:
# Mounted at /dados_cancer_mama
# /dados_cancer_mama

# %% [markdown]
# ---
#
#
# Esse trecho realiza as seguintes ações:
# *   Utiliza o pandas para ler o banco de dados que foi "unzipado"
# *   Limpa dados faltantes
# *   Printa tabela
#
#
#
# ---

# %%
#Reads data from the wdbc.data database that is separated by a comma (sep = ',') and that does not have a header (header = None), (names indicates the name of the columns, they are of the type ID, DIAGNOSTIC, MEDIAS_MEDIDAS, DESVIO_MEDIDAS , BIGGEST_OUTLIERS_MEASUREMENTS)
atributes = ['Id', 'Diagnostic', 'Mean_Radius', 'Mean_Texture', 'Mean_Perimeter', 'Mean_Area', 'Mean_Smoothness', 'Mean_Compactness', 'Mean_Concavity', 'Mean_Concave_Points', 'Mean_Symmetry', 'Mean_Fractal_Dimension',
          'Radius_SE', 'Texture_SE', 'Perimeter_SE', 'Area_SE', 'Smoothness_SE', 'Compactness_SE', 'Concavity_SE', 'Concave_Points_SE', 'Symmetry_SE', 'Fractal_Dimension_SE',
          'Worst_Radius', 'Worst_Texture', 'Worst_Perimeter', 'Worst_Area', 'Worst_Smoothness', 'Worst_Compactness', 'Worst_Concavity', 'Worst_Concave_Points', 'Worst_Symmetry', 'Worst_Fractal_Dimension']

data = pd.read_csv('/dados_cancer_mama/MyDrive/Projeto Estatistica/wdbc.data', sep=',', header = None, names = atributes)


data = data.dropna(axis='rows') # Remove rows with missing data, there is no missing data in this DB



print("Número de linhas e colunas na matriz de atributos:", data.shape) #dados.shape return a tuple (lines, columns)

data.head(data.shape[0])
# Out:
# Número de linhas e colunas na matriz de atributos: (569, 32)
#            Id Diagnostic  Mean_Radius  Mean_Texture  Mean_Perimeter  \
# 0      842302          M        17.99         10.38          122.80
# 1      842517          M        20.57         17.77          132.90
# 2    84300903          M        19.69         21.25          130.00
# 3    84348301          M        11.42         20.38           77.58
# 4    84358402          M        20.29         14.34          135.10
# ..        ...        ...          ...           ...             ...
# 564    926424          M        21.56         22.39          142.00
# 565    926682          M        20.13         28.25          131.20
# 566    926954          M        16.60         28.08          108.30
# 567    927241          M        20.60         29.33          140.10
# 568     92751          B         7.76         24.54           47.92
#
#      Mean_Area  Mean_Smoothness  Mean_Compactness  Mean_Concavity  \
# ...

# %% [markdown]
# # Analise Exploratória dos dados

# %% [markdown]
# ---
#
#
# Conta o número de casos de câncer benigno e maligno a partir da coluna 'Diagnostic' dos dados, armazenando as quantidades em variáveis benig e malig. Em seguida, cria um vetor com esses valores e imprime o total de casos, além das quantidades de casos benignos e malignos.
#
#
#
#
#
# ---

# %%
benig = 0
malig = 0
#counters with numbers of cases of malignant and benign cancer
for diag in data['Diagnostic']:
  if(diag == 'B'):
    benig += 1
  elif(diag == 'M'):
    malig += 1
  else:
    print('error')


vector = np.array([malig, benig])
print("Total:{}\nBenign:{}\nMalignant:{}".format(malig+benig, benig, malig))
label = np.array(['{}{:.2f}{}'.format('Malignant(', (malig/data.shape[0])*100, '%)'), '{}{:.2f}{}'.format('Benign(', (benig/data.shape[0])*100, '%)')])
plt.pie(vector, labels = label, colors = ['red', 'blue'], startangle = 90, shadow = True, explode = [0.1, 0])
plt.legend(title = 'Diagnostic', bbox_to_anchor=(1.05, 1))
plt.show()
# Out:
# Total:569
# Benign:357
# Malignant:212

# %% [markdown]
# ---
#
#
# A função **print_hist_graph** gera gráficos de histogramas para diferentes atributos dos dados, dependendo do tipo especificado. Se o tipo for 'mean', 'standard_error', ou outro, a função ajusta o título e o índice de referência para os atributos. Ela cria uma figura com subplots organizados em uma grade de 5x2, e para cada subplot, plota um histograma do atributo correspondente com uma cor diferente, definindo o título de cada gráfico com o nome do atributo e atualizando o índice de referência e a cor para os próximos gráficos.
#
#
#
# ---

# %%
#Print hist graphs function
def print_hist_graph(data, atributes, type):
  colors = ['red', 'blue', 'yellow', 'green', 'cyan', 'magenta', 'black', 'purple', 'orange', 'olive']
  labels_x = ['µm', 'u', 'µm', '(µm)²', 'u', 'u', 'u', 'u', 'u', 'u']
  if type == 'mean':
    title = 'Mean for each exam'
    ref = 2
  elif type == 'standard_error':
    title = 'Standard error for each exam'
    ref = 12
  else:
    title = 'Worst case for each exam'
    ref = 22

  fig, graph = plt.subplots(5 ,2, figsize =(30,60))
  plt.suptitle(title, y = 0.9)
  c = 0

  for i in range(0, 5):
    for j in range (0, 2):
      graph[i, j].hist(data[atributes[ref]], bins=150, color= colors[c]) #bin -> partitions on x axis
      graph[i, j].set_title(atributes[ref], x = 0.5)
      graph[i, j].set_xlabel(labels_x[c])
      graph[i, j].set_ylabel("Amount")
      ref = ref + 1
      c += 1

# %%
print_hist_graph(data, atributes, 'worst')
#Print on screen the graphs (worst case)

# %%
print_hist_graph(data, atributes, 'standard_error')
#Print on screen the graphs (SE)

# %%
print_hist_graph(data, atributes, 'mean')
#Print on screen the graphs (Means)

# %% [markdown]
# ---
#
#
# O resultado, armazenado na variável **description**, inclui estatísticas como média, desvio padrão, valores mínimo e máximo, e os quartis para cada coluna numérica do DataFrame. Essa informação fornece uma visão geral das distribuições e características estatísticas dos dados.
#
#
#
# ---

# %%
#Get all relevant statistical information
description = data.describe()
description
# Out:
#                  Id  Mean_Radius  Mean_Texture  Mean_Perimeter    Mean_Area  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        Mean_Smoothness  Mean_Compactness  Mean_Concavity  Mean_Concave_Points  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %% [markdown]
# ---
#
#
# O método **data.info()** exibe informações sobre o DataFrame data, incluindo o número total de entradas, o número de entradas não nulas por coluna, e o tipo de dado de cada coluna
#
# ---

# %%
#Information about types
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 32 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Id                       569 non-null    int64
#  1   Diagnostic               569 non-null    object
#  2   Mean_Radius              569 non-null    float64
#  3   Mean_Texture             569 non-null    float64
#  4   Mean_Perimeter           569 non-null    float64
#  5   Mean_Area                569 non-null    float64
#  6   Mean_Smoothness          569 non-null    float64
#  7   Mean_Compactness         569 non-null    float64
#  8   Mean_Concavity           569 non-null    float64
#  9   Mean_Concave_Points      569 non-null    float64
#  10  Mean_Symmetry            569 non-null    float64
#  11  Mean_Fractal_Dimension   569 non-null    float64
#  12  Radius_SE                569 non-null    float64
#  13  Texture_SE               569 non-null    float64
# ...

# %% [markdown]
# ---
#
#
# Imprime os maiores valores encontrados em todas as células dos atributos "worst case" na lista atributes.
#
#
# ---

# %%
#Biggests numbers from all cells
print("Worst's cases among all cells:")

#Worst's atributes starts in 22
for x in atributes[22:]:
  Max = description.loc['max', x]
  print("{}[{:.2f}]".format(x, Max))
# Out:
# Worst's cases among all cells:
# Worst_Radius[36.04]
# Worst_Texture[49.54]
# Worst_Perimeter[251.20]
# Worst_Area[4254.00]
# Worst_Smoothness[0.22]
# Worst_Compactness[1.06]
# Worst_Concavity[1.25]
# Worst_Concave_Points[0.29]
# Worst_Symmetry[0.66]
# Worst_Fractal_Dimension[0.21]

# %% [markdown]
# ---
#
#
# Calcula e imprime as médias dos atributos numéricos listados na faixa de atributos médios, sem a normalização. Ele utiliza o DataFrame description para acessar os valores de média de cada atributo. Os valores são armazenados em um dicionário chamado means_general, com chaves que combinam o nome do atributo com o sufixo '_General'.
#
#
# ---

# %%
#Means (without normalization)
#In description a atributte 'mean' exist, and we can referenciate then with description.loc(atributte_from_describe, atribute_target)
# ex: means_general['Mean_Radius_General'] = general mean radius
means_general = {y + '_General': description.loc['mean', y] for y in atributes[2:12]}

print("Mean of mean atributtes(without normalization);")
for x,y in means_general.items():
  print("{}: {:,.2f}".format(x,y))
# Out:
# Mean of mean atributtes(without normalization);
# Mean_Radius_General: 14.13
# Mean_Texture_General: 19.29
# Mean_Perimeter_General: 91.97
# Mean_Area_General: 654.89
# Mean_Smoothness_General: 0.10
# Mean_Compactness_General: 0.10
# Mean_Concavity_General: 0.09
# Mean_Concave_Points_General: 0.05
# Mean_Symmetry_General: 0.18
# Mean_Fractal_Dimension_General: 0.06

# %% [markdown]
# # Naive Bayes

# %% [markdown]
# ---
#
#
# Import da sklearn e dos métodos utilizados
#
#
# ---

# %%
# Standardize
from sklearn.preprocessing import StandardScaler

# Test accuracy, matrix of false negatives and false positives
import sklearn.metrics as skl

# Train
from sklearn.model_selection import train_test_split

#Train the model
from sklearn.naive_bayes import GaussianNB

# %% [markdown]
# ---
#
#
# Realiza a padronização das colunas numéricas do DataFrame data. Primeiro, define as colunas a serem padronizadas e cria um objeto StandardScaler para ajustar e transformar esses dados. Em seguida, aplica a transformação para padronizar os valores e cria um novo DataFrame com esses dados padronizados.
#
# ---

# %%
#columns to be standardized (numericals)
columns_padronized = atributes[2:]

#Creates a standart object
obj = StandardScaler().fit(data[columns_padronized])

#Create an array of normalized data
data_padronized = obj.transform(data[columns_padronized])

#Transform into data table
data_padronized = pd.DataFrame(data_padronized)

#Define columns
data_padronized.columns = columns_padronized

#Insert column "Diagnostic" after standart the model, we can only strandart numerical values
data_padronized.insert(0, 'Diagnostic', data['Diagnostic'])
data_padronized.head(data_padronized.shape[0])
# Out:
#     Diagnostic  Mean_Radius  Mean_Texture  Mean_Perimeter  Mean_Area  \
# 0            M     1.097064     -2.073335        1.269934   0.984375
# 1            M     1.829821     -0.353632        1.685955   1.908708
# 2            M     1.579888      0.456187        1.566503   1.558884
# 3            M    -0.768909      0.253732       -0.592687  -0.764464
# 4            M     1.750297     -1.151816        1.776573   1.826229
# ..         ...          ...           ...             ...        ...
# 564          M     2.110995      0.721473        2.060786   2.343856
# 565          M     1.704854      2.085134        1.615931   1.723842
# 566          M     0.702284      2.045574        0.672676   0.577953
# 567          M     1.838341      2.336457        1.982524   1.735218
# 568          B    -1.808401      1.221792       -1.814389  -1.347789
#
#      Mean_Smoothness  Mean_Compactness  Mean_Concavity  Mean_Concave_Points  \
# ...

# %% [markdown]
# ---
#
#
# Histograma, agora devidamente padronizado
#
#
# ---

# %%
#Print graphs padronized
print_hist_graph(data_padronized, atributes, "mean" )

# %% [markdown]
# ---
#
#
# Prepara os dados para treinamento e teste de um modelo de machine learning. Primeiro, ele separa a coluna 'Diagnostic' do DataFrame data_padronized para criar duas variáveis: X, que contém os dados numéricos padronizados sem a coluna 'Diagnostic', e Y, que contém a coluna 'Diagnostic'. Em seguida, ele divide os dados em conjuntos de treinamento e teste usando a função train_test_split, com 30% dos dados reservados para teste (test_size=0.3). Os conjuntos resultantes são X_train e Y_train para treinamento, e X_test e Y_test para teste.
#
#
#
# ---

# %%
#Data table that will be trained
X = data_padronized.drop('Diagnostic', axis = 1)

#Correct source of diagnoses
Y = data_padronized['Diagnostic']

#Split in two sets, train and test, function "train_test_split" return a 4 tuple
#X_train -> Data used to train the model
#X_test -> Data used to test the model
#Y_train -> Diagnostics used to train the model
#Y_test -> Diagnostics used to test the model

#Test_size -> Proportion of set used for testing
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=42)

# %% [markdown]
# ---
#
#
# Treina um modelo de Naive Bayes Gaussiano (GaussianNB) usando os dados de treinamento (X_train, Y_train). Após o treinamento, o modelo faz previsões sobre os dados de teste (X_test). Imprime o número de previsões incorretas comparadas ao total de pontos no conjunto de teste, a precisão do modelo, e a matriz de confusão.
#
#
#
# ---

# %%
model = GaussianNB()

#Model training
#Parameters (data, expected_results)
Y_pred = model.fit(X_train, Y_train)

#Predictions with the data test
predictions = model.predict(X_test)

print("Number of incorrectly labeled points out of a total of %d points: %d" % (X_test.shape[0], (Y_test != predictions).sum()))

print("Accuracy:", skl.accuracy_score(Y_test, predictions))
matrix = skl.confusion_matrix(Y_test, predictions)

print("True positive:", skl.confusion_matrix(Y_test, predictions)[0][0])
print("True negative:", skl.confusion_matrix(Y_test, predictions)[1][1])
print("False positive:", skl.confusion_matrix(Y_test, predictions)[0][1])
print("False negative:", skl.confusion_matrix(Y_test, predictions)[1][0])
# Out:
# Number of incorrectly labeled points out of a total of 171 points: 11
# Accuracy: 0.935672514619883
# True positive: 103
# True negative: 57
# False positive: 5
# False negative: 6
